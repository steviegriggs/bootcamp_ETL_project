# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib as plt

# %%
df_price = pd.read_csv('bittrex-bitcoin-pairs/BTC_PAIRS_PRICE.csv')

# %%
df_price1 = df_price.drop([2745])

# %%
df_price1.describe()
# Out:
#           UNIX_Time     BTC_2GIVE       BTC_ABY       BTC_ADA       BTC_ADT  \
# count  4.016100e+04  4.016100e+04  4.016100e+04  40161.000000  4.016100e+04
# mean   1.522503e+09  7.763534e-07  8.256333e-07      0.000022  4.113052e-06
# std    6.907297e+05  5.876774e-08  3.692329e-08      0.000002  3.290500e-07
# min    1.521306e+09  6.600000e-07  7.500000e-07      0.000017  3.470000e-06
# 25%    1.521905e+09  7.200000e-07  8.000000e-07      0.000021  3.840000e-06
# 50%    1.522503e+09  7.700000e-07  8.200000e-07      0.000022  4.060000e-06
# 75%    1.523101e+09  8.300000e-07  8.400000e-07      0.000022  4.330000e-06
# max    1.523699e+09  9.100000e-07  9.500000e-07      0.000028  6.150000e-06
#
#             BTC_ADX      BTC_AEON       BTC_AMP       BTC_ANT      BTC_ARDR  \
# count  40161.000000  40161.000000  40161.000000  40161.000000  40161.000000
# mean       0.000088      0.000228      0.000034      0.000367      0.000034
# ...

# %%
df2a = df_price[['UNIX_Time','BTC_ETH']]
df2a = df2a[(df2a.T != 0).any()]
df3a = df2a['BTC_ETH'].diff()
df3a.head()
# Out:
# 0         NaN
# 1    0.000005
# 2   -0.000300
# 3   -0.000060
# 4    0.000000
# Name: BTC_ETH, dtype: float64

# %%
df2a = df_price[['BTC_ETH']]
df2a = df2a[(df2a.T != 0).any()]
df3a = df2a['BTC_ETH'].diff()
df3a.head()

# %%
df2a[['UNIX_Time']].loc()


# df4a = df3a/df2a
# df4a.head()
# Out:
#     UNIX_Time
# 0  1521306274
# 1  1521306334
# 2  1521306393
# 3  1521306453
# 4  1521306512

# %%
df_price['UNIX_Time'].iloc[2745]
# Out:
# 1521469869

# %%
df2a = df_price[['BTC_ETH']]
df2a = df2a[(df2a.T != 0).any()]
df3a = df2a.diff()
df4a = df3a/df2a
df4a.describe()
# Out:
#             BTC_ETH
# count  40160.000000
# mean      -0.000007
# std        0.002463
# min       -0.021169
# 25%       -0.000626
# 50%        0.000000
# 75%        0.000605
# max        0.014275

# %%
df2b = df_price[['BTC_LTC']]
df2b = df2b[(df2b.T != 0).any()]
df3b = df2b.diff()
df4b = df3b/df2b
df4b.describe()
# Out:
#             BTC_LTC
# count  40160.000000
# mean      -0.000009
# std        0.002690
# min       -0.014466
# 25%       -0.000350
# 50%        0.000000
# 75%        0.000305
# max        0.022803

# %%
df2c = df_price[['BTC_ZEC']]
df2c = df2c[(df2c.T != 0).any()]
df3c = df2c.diff()
df4c = df3c/df2c
df4c.describe()
# Out:
#             BTC_ZEC
# count  4.016000e+04
# mean  -1.827321e-06
# std    2.318773e-03
# min   -1.372524e-02
# 25%   -3.697119e-07
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.560936e-02

# %%
df2d = df_price[['BTC_DASH']]
df2d = df2d[(df2d.T != 0).any()]
df3d = df2d.diff()
df4d = df3d/df2d
df4d.describe()
# Out:
#            BTC_DASH
# count  40160.000000
# mean      -0.000005
# std        0.002596
# min       -0.017157
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.020915

# %%
df2e = df_price[['BTC_XRP']]
df2e = df2e[(df2e.T != 0).any()]
df3e = df2e.diff()
df4e = df3e/df2e
df4e.describe()
# Out:
#             BTC_XRP
# count  40160.000000
# mean      -0.000002
# std        0.002131
# min       -0.018829
# 25%       -0.000287
# 50%        0.000000
# 75%        0.000280
# max        0.021572

# %%
df2.head()
# Out:
#     BTC_ETH
# 0  0.072955
# 1  0.072960
# 2  0.072660
# 3  0.072600
# 4  0.072600

# %%
df3 = df2.diff()

# %%
df4 = df3/df2

# %%
df4.describe()
# Out:
#             BTC_ETH
# count  40160.000000
# mean      -0.000007
# std        0.002463
# min       -0.021169
# 25%       -0.000626
# 50%        0.000000
# 75%        0.000605
# max        0.014275

# %%
df4.plot(kind='line')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-d141c4b3e48e> in <module>
# ----> 1 df4.scatter()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'scatter'
